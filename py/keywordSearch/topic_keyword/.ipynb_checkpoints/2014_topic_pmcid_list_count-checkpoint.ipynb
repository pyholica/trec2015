# %%
# coding: utf-8

# In[6]:

from elasticsearch import Elasticsearch
import os, re
es = Elasticsearch([{'host':'210.107.192.201', 'port':9200}])


# In[ ]:

file = open('2014_mix_topic_final.csv', 'rb')
newpath = './2014_mixed_topic_keyword/'
if not os.path.exists(newpath): os.makedirs(newpath)
    
topics = file.readlines()
cnt = 1
for topic in topics:
    topic = topic.lower()
    
    topic = re.sub('[^a-zA-Z0-9-_*.]', ' ', topic)
    print("{} : ".format(cnt) + topic)
    
    
    res = es.search(index="dfr_ngram_total_new",doc_type="article", q=topic
                    #,size=10000
                    ,search_type = "count"
                    ,request_timeout=1000000
                    #,search_type="count"
                    ,fields=['pmcid'])
    print(res['hits']['hits'])
    total = res['hits']['total']
    #size = total/10
    
    #print "total : {0}".format(total)
    #print "size : {0}".format(size)
# Out:
# 1 : chest pain radiating ekg hypercholesterolemia burning chest dyspnea heart related burning nausea hypercholesterolaemia diaphoresis diabetes family history of disease pressing pain obesity hypertension pain nos pain
# [{u'_score': 0.4979002, u'_type': u'article', u'_id': u'2801475', u'fields': {u'pmcid': [u'2801475']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.4678497, u'_type': u'article', u'_id': u'3809224', u'fields': {u'pmcid': [u'3809224']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.42580152, u'_type': u'article', u'_id': u'2760694', u'fields': {u'pmcid': [u'2760694']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.41820878, u'_type': u'article', u'_id': u'2776372', u'fields': {u'pmcid': [u'2776372']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.4069456, u'_type': u'article', u'_id': u'3712160', u'fields': {u'pmcid': [u'3712160']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.39857632, u'_type': u'article', u'_id': u'3734632', u'fields': {u'pmcid': [u'3734632']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3919852, u'_type': u'article', u'_id': u'3760668', u'fields': {u'pmcid': [u'3760668']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.39183262, u'_type': u'article', u'_id': u'3258729', u'fields': {u'pmcid': [u'3258729']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.38829508, u'_type': u'article', u'_id': u'3430116', u'fields': {u'pmcid': [u'3430116']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.36018133, u'_type': u'article', u'_id': u'2790183', u'fields': {u'pmcid': [u'2790183']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.35720506, u'_type': u'article', u'_id': u'2935984', u'fields': {u'pmcid': [u'2935984']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.35657093, u'_type': u'article', u'_id': u'2917397', u'fields': {u'pmcid': [u'2917397']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.35234603, u'_type': u'article', u'_id': u'3328892', u'fields': {u'pmcid': [u'3328892']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3480365, u'_type': u'article', u'_id': u'2799444', u'fields': {u'pmcid': [u'2799444']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3410115, u'_type': u'article', u'_id': u'2752757', u'fields': {u'pmcid': [u'2752757']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3345251, u'_type': u'article', u'_id': u'3318207', u'fields': {u'pmcid': [u'3318207']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.33356053, u'_type': u'article', u'_id': u'3476012', u'fields': {u'pmcid': [u'3476012']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3304513, u'_type': u'article', u'_id': u'2948152', u'fields': {u'pmcid': [u'2948152']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3192548, u'_type': u'article', u'_id': u'3526875', u'fields': {u'pmcid': [u'3526875']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.31332973, u'_type': u'article', u'_id': u'3514348', u'fields': {u'pmcid': [u'3514348']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.31098005, u'_type': u'article', u'_id': u'3658219', u'fields': {u'pmcid': [u'3658219']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3086835, u'_type': u'article', u'_id': u'3311440', u'fields': {u'pmcid': [u'3311440']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3073254, u'_type': u'article', u'_id': u'3375156', u'fields': {u'pmcid': [u'3375156']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0
}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.40016586, u'_type': u'article', u'_id': u'3587910', u'fields': {u'pmcid': [u'3587910']}, u'_index': u'dfr_ngram_total_new'}, {u'_score': 0.3999029, u'_type': u'article', u'_id': u'3590970', u'fields': {u'pmcid': [u'3590970']}, u'_index': u'df ...
# 1 : leukocytes in urine coronary artery aneurysm conjunctivitis normochromic normocytic anaemia erythrocyte sedimentation rate irritability feet hands desquamation echocardiogram fever high fever fingers of skin tenderness physical exam findings physical exam findings elevated aminotransferase urine leukocytes toes identified desquamation of skin strawberry tongue coronary arteries node low albumin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5334b62ece72> in <module>()
#      28                     ,request_timeout=1000000
#      29                     #,search_type="count"
# ---> 30                     ,fields=['pmcid'])
#      31     print(res['hits']['hits'])
#      32     total = res['hits']['total']
#
# C:\Anaconda\lib\site-packages\elasticsearch\client\utils.pyc in _wrapped(*args, **kwargs)
#      67                 if p in kwargs:
#      68                     params[p] = kwargs.pop(p)
# ---> 69             return func(*args, params=params, **kwargs)
#      70         return _wrapped
#      71     return _wrapper
#
# C:\Anaconda\lib\site-packages\elasticsearch\client\__init__.pyc in search(self, index, doc_type, body, params)
#     504             index = '_all'
#     505         _, data = self.transport.perform_request('GET', _make_path(index, doc_type, '_search'),
# --> 506             params=params, body=body)
#     507         return data
#     508
#
# C:\Anaconda\lib\site-packages\elasticsearch\transport.pyc in perform_request(self, method, url, params, body)
#     305
#     306             try:
# --> 307                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     308
#     309             except TransportError as e:
#
# C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.pyc in perform_request(self, method, url, params, body, timeout, ignore)
#      72                 method = method.encode('utf-8')
#      73
# ---> 74             response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#      75             duration = time.time() - start
#      76             raw_data = response.data.decode('utf-8')
#
# C:\Anaconda\lib\site-packages\urllib3\connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda\lib\site-packages\urllib3\connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     370         try:
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#     374                 httplib_response = conn.getresponse()
#
# C:\Anaconda\lib\httplib.pyc in getresponse(self, buffering)
#    1065         response = self.response_class(*args, **kwds)
#    1066
# -> 1067         response.begin()
#    1068         assert response.will_close != _UNKNOWN
#    1069         self.__state = _CS_IDLE
#
# C:\Anaconda\lib\httplib.pyc in begin(self)
#     407         # read until we get a non-100 response
#     408         while True:
# --> 409             version, status, reason = self._read_status()
#     410             if status != CONTINUE:
#     411                 break
#
# C:\Anaconda\lib\httplib.pyc in _read_status(self)
#     363     def _read_status(self):
#     364         # Initialize with Simple-Response defaults
# --> 365         line = self.fp.readline(_MAXLINE + 1)
#     366         if len(line) > _MAXLINE:
#     367             raise LineTooLong("header line")
#
# C:\Anaconda\lib\socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
