# %%
# coding: utf-8

# In[42]:




from datetime import datetime
from elasticsearch import Elasticsearch
from pymongo import MongoClient
import sys




client = MongoClient('mongodb://210.107.192.201:27017')
es = Elasticsearch([{'host':'210.107.192.201', 'port':9200}])

db = client.trec

collection = db.article


# In[48]:
def indexing(index_name, pmcidListFile):

    f = open(pmcidListFile, 'r')
    pmcidlist = list(f)


    # In[49]:

    for pmid in pmcidlist:
        pmid = str(pmid).strip()

        #res = es.search(index="dfr_ngram_total_new",doc_type="article", q=pmid, id=pmid, size=1, request_timeout=1000000)
        res = es.get(index='dfr_total', doc_type='article', id=pmid)
        #result = res['hits']['hits']['_source']
        result = res['_source']
        input_D = {
            'pmcid' : result['pmcid'],
            'title' : result['title'],
            'abstract' : result['abstract'],
            'body' :  result['body']
        }

        #input_D

        res = es.index(index=index_name, doc_type='article', id=pmid, body=input_D, timeout=3600, request_timeout=100000)

for topicNum in range(1, 31):
    index_name = 'dfr_ngram_2015_desc_topic{0}'.format(topicNum)
    pmcidListFile = '2015_desc_topic_keyword/topic{0}.csv'.format(topicNum)
    indexing(index_name, pmcidListFile)
    
    #index_name = "dfr_total"

    # In[ ]:
# Out:
# WARNING:elasticsearch:GET http://localhost:9200/dfr_ngram_total_new/article/2591431 [status:N/A request:2.036s]
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.py", line 74, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 597, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Anaconda\lib\site-packages\urllib3\util\retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 544, in urlopen
#     body=body, headers=headers)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 349, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "C:\Anaconda\lib\httplib.py", line 995, in request
#     self._send_request(method, url, body, headers)
#   File "C:\Anaconda\lib\httplib.py", line 1029, in _send_request
#     self.endheaders(body)
#   File "C:\Anaconda\lib\httplib.py", line 991, in endheaders
#     self._send_output(message_body)
#   File "C:\Anaconda\lib\httplib.py", line 844, in _send_output
#     self.send(msg)
#   File "C:\Anaconda\lib\httplib.py", line 806, in send
#     self.connect()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 155, in connect
#     conn = self._new_conn()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 134, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\util\connection.py", line 88, in create_connection
#     raise err
# ProtocolError: ('Connection aborted.', error(10061, ''))
# WARNING:elasticsearch:GET http://localhost:9200/dfr_ngram_total_new/article/2591431 [status:N/A request:2.020s]
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.py", line 74, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 597, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Anaconda\lib\site-packages\urllib3\util\retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 544, in urlopen
#     body=body, headers=headers)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 349, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "C:\Anaconda\lib\httplib.py", line 995, in request
#     self._send_request(method, url, body, headers)
#   File "C:\Anaconda\lib\httplib.py", line 1029, in _send_request
#     self.endheaders(body)
#   File "C:\Anaconda\lib\httplib.py", line 991, in endheaders
#     self._send_output(message_body)
#   File "C:\Anaconda\lib\httplib.py", line 844, in _send_output
#     self.send(msg)
#   File "C:\Anaconda\lib\httplib.py", line 806, in send
#     self.connect()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 155, in connect
#     conn = self._new_conn()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 134, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\util\connection.py", line 88, in create_connection
#     raise err
# ProtocolError: ('Connection aborted.', error(10061, ''))
# WARNING:elasticsearch:GET http://localhost:9200/dfr_ngram_total_new/article/2591431 [status:N/A request:2.030s]
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.py", line 74, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 597, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Anaconda\lib\site-packages\urllib3\util\retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 544, in urlopen
#     body=body, headers=headers)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 349, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "C:\Anaconda\lib\httplib.py", line 995, in request
#     self._send_request(method, url, body, headers)
#   File "C:\Anaconda\lib\httplib.py", line 1029, in _send_request
#     self.endheaders(body)
#   File "C:\Anaconda\lib\httplib.py", line 991, in endheaders
#     self._send_output(message_body)
#   File "C:\Anaconda\lib\httplib.py", line 844, in _send_output
#     self.send(msg)
#   File "C:\Anaconda\lib\httplib.py", line 806, in send
#     self.connect()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 155, in connect
#     conn = self._new_conn()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 134, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\util\connection.py", line 88, in create_connection
#     raise err
# ProtocolError: ('Connection aborted.', error(10061, ''))
# WARNING:elasticsearch:GET http://localhost:9200/dfr_ngram_total_new/article/2591431 [status:N/A request:2.013s]
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.py", line 74, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 597, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Anaconda\lib\site-packages\urllib3\util\retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 544, in urlopen
#     body=body, headers=headers)
#   File "C:\Anaconda\lib\site-packages\urllib3\connectionpool.py", line 349, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "C:\Anaconda\lib\httplib.py", line 995, in request
#     self._send_request(method, url, body, headers)
#   File "C:\Anaconda\lib\httplib.py", line 1029, in _send_request
#     self.endheaders(body)
#   File "C:\Anaconda\lib\httplib.py", line 991, in endheaders
#     self._send_output(message_body)
#   File "C:\Anaconda\lib\httplib.py", line 844, in _send_output
#     self.send(msg)
#   File "C:\Anaconda\lib\httplib.py", line 806, in send
#     self.connect()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 155, in connect
#     conn = self._new_conn()
#   File "C:\Anaconda\lib\site-packages\urllib3\connection.py", line 134, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "C:\Anaconda\lib\site-packages\urllib3\util\connection.py", line 88, in create_connection
#     raise err
# ProtocolError: ('Connection aborted.', error(10061, ''))
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-b3c3a6269f26> in <module>()
#      53     index_name = 'dfr_ngram_2015_desc_topic{0}'.format(topicNum)
#      54     pmcidListFile = '2015_desc_topic_keyword/topic{0}.csv'.format(topicNum)
# ---> 55     indexing(index_name, pmcidListFile)
#      56
#      57     #index_name = "dfr_total"
#
# <ipython-input-2-b3c3a6269f26> in indexing(index_name, pmcidListFile)
#      36
#      37         #res = es.search(index="dfr_ngram_total_new",doc_type="article", q=pmid, id=pmid, size=1, request_timeout=1000000)
# ---> 38         res = es.get(index='dfr_ngram_total_new', doc_type='article', id=pmid)
#      39         #result = res['hits']['hits']['_source']
#      40         result = res['_source']
#
# C:\Anaconda\lib\site-packages\elasticsearch\client\utils.pyc in _wrapped(*args, **kwargs)
#      67                 if p in kwargs:
#      68                     params[p] = kwargs.pop(p)
# ---> 69             return func(*args, params=params, **kwargs)
#      70         return _wrapped
#      71     return _wrapper
#
# C:\Anaconda\lib\site-packages\elasticsearch\client\__init__.pyc in get(self, index, id, doc_type, params)
#     317                 raise ValueError("Empty value passed for a required argument.")
#     318         _, data = self.transport.perform_request('GET', _make_path(index, doc_type, id),
# --> 319             params=params)
#     320         return data
#     321
#
# C:\Anaconda\lib\site-packages\elasticsearch\transport.pyc in perform_request(self, method, url, params, body)
#     305
#     306             try:
# --> 307                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     308
#     309             except TransportError as e:
#
# C:\Anaconda\lib\site-packages\elasticsearch\connection\http_urllib3.pyc in perform_request(self, method, url, params, body, timeout, ignore)
#      83         except Exception as e:
#      84             self.log_request_fail(method, full_url, body, time.time() - start, exception=e)
# ---> 85             raise ConnectionError('N/A', str(e), e)
#      86
#      87         if not (200 <= response.status < 300) and response.status not in ignore:
#
# ConnectionError: ConnectionError(('Connection aborted.', error(10061, ''))) caused by: ProtocolError(('Connection aborted.', error(10061, '')))
