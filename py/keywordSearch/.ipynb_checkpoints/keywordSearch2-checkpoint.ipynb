# %%
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host':'210.107.192.201', 'port':9200}])

# %%
csvfile = open('2014_summary.csv', 'rb')
count = 0
doc = csvfile.readline()
count += 1
topiclist = []
for count in range(1, 31):
    print(count)
    title = "Topic number"
    print(doc)
    if title in doc:
        query = {}
        doc = csvfile.readline()
        #print(doc)
        while "Topic number : " not in doc:
            pnt = doc.find(":")
            #print(doc)
            word = doc[pnt+2:]
            #print(word)
            query[word] = "word"
            doc = csvfile.readline()
            print("hello")
        words = query.keys()
        #print(words)
        topiclist.append(words)
        doc = csvfile.readline()
    #print(doc)
#topicwords = open("topicwords.txt", "w")
#for words in topiclist:
#    topicwords.write(words)
#topicwords.close()
csvfile.close()
# Out:
# 1
# Topic number : 1
#
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# 2
# [sosy],Concept Name : LOOSE STOOLS
#
# 3
# ,Preferred Name : Diarrhea
#
# 4
# [sosy],Concept Name : Loose stools
#
# 5
# ,Preferred Name : Loose stool
#
# 6
# [sosy],Concept Name : Cough
#
# 7
# ,Preferred Name : Coughing
#
# 8
# [diap],Concept Name : Chest X-ray
#
# 9
# ,Preferred Name : Chest X-ray
#
# 10
# [dsyn],Concept Name : Lung Infiltrate
#
# 11
# ,Preferred Name : Infiltrate of lung
#
# 12
# Topic number : 3
#
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# 13
# [dsyn],Concept Name : Conjunctivitis
#
# 14
# ,Preferred Name : Conjunctivitis
#
# 15
# [dsyn],Concept Name : Strawberry tongue
#
# 16
# ,Preferred Name : Strawberry tongue
#
# 17
# [bpoc],Concept Name : Toes
#
# 18
# ,Preferred Name : Toes
#
# 19
# [bpoc],Concept Name : Coronary Arteries
#
# 20
# ,Preferred Name : Coronary artery
#
# 21
# [bpoc],Concept Name : Coronary Arteries
#
# 22
# ,Preferred Name : Coronary artery
#
# 23
# [bpoc],Concept Name : Coronary Arteries
#
# 24
# ,Preferred Name : Coronary artery
#
# 25
# [bpoc],Concept Name : Coronary Arteries
#
# 26
# ,Preferred Name : Coronary artery
#
# 27
# [bpoc],Concept Name : Coronary Arteries
#
# 28
# ,Preferred Name : Coronary artery
#
# 29
# [bpoc],Concept Name : Coronary Arteries
#
# 30
# ,Preferred Name : Coronary artery

# %%
sentence = "hello : world"
sentence.find(": ")
sentence[8:]
list1 = []
list1.append("hello")
print list1
dic1 = {}
dic1["hello"] ="word"
dic1["good"] = "word"
list1.append(dic1.keys())
print list1
if "hello" not in sentence:
    print "true"
# Out:
# ['hello']
# ['hello', ['good', 'hello']]

# %%
import csv
import os
folder_name = "pmclist_topic1"
index_name = "dfr_total"
#analyzer_name = "edge_ngram_analyzer"
topicNum = ""

# summary query

csvfile = open('2014_summary.csv', 'rb')
reader = csv.DictReader(csvfile)
doc=reader.next()
#list_sum = list(csvfile.readlines())
#print(list_sum[3])
query = doc['summary']
print(doc['summary'])
csvfile.close()

# search list
newpath = './{0}/'.format(folder_name)
if not os.path.exists(newpath): os.makedirs(newpath)
target = open("{0}topic{1}.csv".format(newpath, topicNum), 'w')
#res = es.search(index=index_name2,doc_type="article", q=query, size=40000)
res = es.search(index=index_name,doc_type="article"
                , q=query
                , size=10000
                , timeout=1000000
                , request_timeout=1000000)
count = 0
for doc in res['hits']['hits']:
    count += 1
    text = '{0}, {1}, {2}'.format(count,doc['_source']['pmcid'],doc['_score'] )
    #print (text)
    target.write(text + '\n')
target.close()
print("finished")
